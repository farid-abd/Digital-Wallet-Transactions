# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
wallet_trans = pd.read_csv('digital_wallet_transactions.csv')

# %%
wallet_trans
# Out:
#        idx                        transaction_id     user_id  \
# 0        1  4dac3ea3-6492-46ec-80b8-dc45c3ad0b14  USER_05159
# 1        2  a903ed9f-eb84-47e7-b8aa-fd1786c919cf  USER_07204
# 2        3  2a393013-733c-4add-9f09-bed1eeb33676  USER_00903
# 3        4  9a07ad19-4673-4794-9cd2-9b139f39c715  USER_01769
# 4        5  76418260-c985-4011-979d-0914604d0d68  USER_03544
# ...    ...                                   ...         ...
# 4995  4996  2cad1456-e6dd-4d0f-9463-a071a462c2ae  USER_03918
# 4996  4997  df3984f6-cf9d-418f-ad2e-f9d4fff69cd5  USER_09281
# 4997  4998  1c4cd450-785d-4f4c-a08d-cb7c17db9b0c  USER_05939
# 4998  4999  f88d6fb3-d747-4963-82f3-92e181a93771  USER_09925
# 4999  5000  5e1a9245-9f2b-4ff9-bd56-26fd20c8eae2  USER_08419
#
#       transaction_date product_category               product_name  \
# 0     2023-08-19 03:32     Rent Payment          2BHK Flat Deposit
# 1     2023-08-19 04:37         Gas Bill  Commercial Gas Connection
# 2     2023-08-19 05:52       Bus Ticket               Semi-Sleeper
# 3     2023-08-19 06:35    Internet Bill          4G Unlimited Plan
# 4     2023-08-19 06:36   Loan Repayment              Home Loan EMI
# ...                ...              ...                        ...
# 4995  2024-08-17 19:39    Internet Bill          4G Unlimited Plan
# 4996  2024-08-17 19:42    Education Fee  Python Programming Course
# 4997  2024-08-17 23:24     Movie Ticket          Avengers: Endgame
# 4998  2024-08-18 00:28  Mobile Recharge             Data Pack 50GB
# 4999  2024-08-18 01:15    Food Delivery          Vegetable Biryani
#
#          merchant_name  product_amount  transaction_fee  cashback  \
# 0               Airbnb         1525.39            36.69     19.19
# 1            Adani Gas         1495.40            28.19     89.99
# 2       MakeMyTrip Bus         1267.71            11.36     95.70
# 3     Airtel Broadband         9202.63             6.41     82.24
# 4            Axis Bank         3100.58            41.15     40.47
# ...                ...             ...              ...       ...
# 4995    BSNL Broadband         9496.45            37.25     87.47
# 4996         Unacademy          710.40            14.01     55.24
# 4997       PVR Cinemas         2750.06            48.69     72.10
# 4998              BSNL         9976.19            21.96     40.44
# 4999         Foodpanda         1683.63            11.43     70.44
#
#       loyalty_points payment_method transaction_status merchant_id  \
# 0                186     Debit Card         Successful  MERCH_0083
# 1                182            UPI         Successful  MERCH_0163
# 2                994            UPI         Successful  MERCH_0320
# 3                409     Debit Card         Successful  MERCH_0194
# 4                837     Debit Card         Successful  MERCH_0504
# ...              ...            ...                ...         ...
# 4995             284            UPI         Successful  MERCH_0203
# 4996             538    Credit Card         Successful  MERCH_0480
# 4997             652  Bank Transfer         Successful  MERCH_0411
# 4998             614            UPI         Successful  MERCH_0524
# 4999             936            UPI         Successful  MERCH_0446
#
#      device_type  location
# 0            iOS     Urban
# 1            iOS     Urban
# 2            iOS     Urban
# 3        Android     Urban
# 4        Android     Urban
# ...          ...       ...
# 4995     Android     Rural
# 4996         iOS     Urban
# 4997     Android  Suburban
# 4998         iOS  Suburban
# 4999         Web     Urban
#
# [5000 rows x 16 columns]

# %%
wallet_trans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   idx                 5000 non-null   int64
#  1   transaction_id      5000 non-null   object
#  2   user_id             5000 non-null   object
#  3   transaction_date    5000 non-null   object
#  4   product_category    5000 non-null   object
#  5   product_name        5000 non-null   object
#  6   merchant_name       5000 non-null   object
#  7   product_amount      5000 non-null   float64
#  8   transaction_fee     5000 non-null   float64
#  9   cashback            5000 non-null   float64
#  10  loyalty_points      5000 non-null   int64
#  11  payment_method      5000 non-null   object
#  12  transaction_status  5000 non-null   object
#  13  merchant_id         5000 non-null   object
#  14  device_type         5000 non-null   object
#  15  location            5000 non-null   object
# dtypes: float64(3), int64(2), object(11)
# memory usage: 625.1+ KB

# %%
sns.heatmap(wallet_trans.isnull(), yticklabels=False, cbar=False, cmap='viridis')
# Out:
# <Axes: >

# %%
wallet_trans.describe()
# Out:
#                idx  product_amount  transaction_fee     cashback  \
# count  5000.000000     5000.000000      5000.000000  5000.000000
# mean   2500.500000     4957.502722        25.188874    50.658782
# std    1443.520003     2885.034160        14.535298    28.522467
# min       1.000000       10.090000         0.010000     0.000000
# 25%    1250.750000     2453.977500        12.665000    26.495000
# 50%    2500.500000     4943.685000        25.070000    51.390000
# 75%    3750.250000     7444.815000        37.947500    75.067500
# max    5000.000000     9996.950000        49.990000   100.000000
#
#        loyalty_points
# count     5000.000000
# mean       498.790400
# std        288.962434
# min          0.000000
# 25%        246.000000
# 50%        504.000000
# 75%        749.000000
# max        999.000000

# %%
# count the unique values in product_category
wallet_trans.product_category.value_counts()
# Out:
# Streaming Service    299
# Education Fee        286
# Hotel Booking        274
# Water Bill           273
# Movie Ticket         272
# Food Delivery        259
# Taxi Fare            256
# Electricity Bill     252
# Rent Payment         251
# Gas Bill             250
# Loan Repayment       245
# Online Shopping      243
# Mobile Recharge      241
# Grocery Shopping     238
# Bus Ticket           235
# Internet Bill        233
# Gaming Credits       231
# Insurance Premium    225
# Gift Card            221
# Flight Booking       216
# Name: product_category, dtype: int64

# %%
wallet_trans.transaction_status.value_counts()
# Out:
# Successful    4755
# Failed         146
# Pending         99
# Name: transaction_status, dtype: int64

# %%
wallet_trans.payment_method.value_counts()
# Out:
# Bank Transfer     1045
# Debit Card        1022
# UPI                999
# Credit Card        992
# Wallet Balance     942
# Name: payment_method, dtype: int64

# %%
# Investigating the relationship between payment methods and transaction success rates

# %% [markdown]
# From data above, we can see that every payment method have high successful rate. But the next question is, what is the dominant method in the each successful, failed and pending status. Or in other word, what is the most successful, failed, and pending method between those.

# %%
sns.barplot(x='payment_method',y='number_of_status', hue='transaction_status', data=methods)
# Out:
# <Axes: xlabel='payment_method', ylabel='number_of_status'>

# %%
crosstab = pd.crosstab(wallet_trans['payment_method'], wallet_trans['transaction_status'])

crosstab.plot(kind='bar', figsize=(10, 6), stacked=True)
plt.xlabel('Payment Method')
plt.ylabel('number_of_status')
plt.xticks(rotation=45)
plt.legend(title='Transaction Status')
plt.show()
crosstab
# Out:
# transaction_status  Failed  Pending  Successful
# payment_method
# Bank Transfer           29       18         998
# Credit Card             35       24         933
# Debit Card              25        9         988
# UPI                     25       24         950
# Wallet Balance          32       24         886

# %% [markdown]
# Bank transfer is the most successful payment method because it have the high number in there. Followed by debit card and then between credit card and UPI. Wallet balance is the last option people choose for paying their transaction.
